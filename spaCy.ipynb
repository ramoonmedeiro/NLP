# %% [markdown]
# # Texto com spaCy

# %% [markdown]
# ## Baixando pacotes e modelos pré-treinados

# %%
# !pip install -U spacy==3.2.0

# %%
# Baixando modelo "grande" pré-treinado (pequeno=sm, medio=md)
# !python -m spacy download 'pt_core_news_lg'

# %%
import spacy
# Out:
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")

# %%
# Carregando modelo para nlp
nlp = spacy.load('pt_core_news_lg')

# %%
# Pipeline de criação de tokens
nlp.pipe_names
# Out:
# ['tok2vec', 'morphologizer', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %% [markdown]
# ## Primeiros Testes

# %%
tokens_doc = nlp('Hoje tem jogo do Lakers x Boston Celtics. Saudades do tempo de Kobe Bryant vs Paul Pierce')

# %%
type(tokens_doc)
# Out:
# spacy.tokens.doc.Doc

# %%
for token in tokens_doc:
  print(token)
# Out:
# Hoje
# tem
# jogo
# do
# Lakers
# x
# Boston
# Celtics
# .
# Saudades
# do
# tempo
# de
# Kobe
# Bryant
# vs
# Paul
# Pierce

# %%
print(f'Tokens: {[token.text for token in tokens_doc]}')
print(f'StopWord: {[token.is_stop for token in tokens_doc]}')
print(f'Alfanumérico: {[token.is_alpha for token in tokens_doc]}')
print(f'Maiúsculo: {[token.is_upper for token in tokens_doc]}')
print(f'Pontuação: {[token.is_punct for token in tokens_doc]}')
print(f'Número: {[token.like_num for token in tokens_doc]}')
print(f'Sentença Inicial: {[token.is_sent_start for token in tokens_doc]}')
print(f'Formato: {[token.shape_ for token in tokens_doc]}')
# Out:
# Tokens: ['Hoje', 'tem', 'jogo', 'do', 'Lakers', 'x', 'Boston', 'Celtics', '.', 'Saudades', 'do', 'tempo', 'de', 'Kobe', 'Bryant', 'vs', 'Paul', 'Pierce']
# StopWord: [False, True, False, True, False, False, False, False, False, False, True, True, True, False, False, False, False, False]
# Alfanumérico: [True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True]
# Maiúsculo: [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False]
# Pontuação: [False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False]
# Número: [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False]
# Sentença Inicial: [True, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False]
# Formato: ['Xxxx', 'xxx', 'xxxx', 'xx', 'Xxxxx', 'x', 'Xxxxx', 'Xxxxx', '.', 'Xxxxx', 'xx', 'xxxx', 'xx', 'Xxxx', 'Xxxxx', 'xx', 'Xxxx', 'Xxxxx']

# %% [markdown]
# ## Part-Of-Speech (POS)

# %%
for token in tokens_doc:
  print(f'{token} - {token.pos_} - {token.dep_} - {token.lemma_} - {token.shape_}')
# Out:
# Hoje - ADV - advmod - Hoje - Xxxx
# tem - VERB - ROOT - ter - xxx
# jogo - NOUN - obj - jogar - xxxx
# do - ADP - case - do - xx
# Lakers - PROPN - nmod - Lakers - Xxxxx
# x - PROPN - flat:name - x - x
# Boston - PROPN - flat:name - Boston - Xxxxx
# Celtics - PROPN - flat:name - Celtics - Xxxxx
# . - PUNCT - punct - . - .
# Saudades - NOUN - ROOT - Saudades - Xxxxx
# do - ADP - case - do - xx
# tempo - NOUN - nmod - tempo - xxxx
# de - ADP - case - de - xx
# Kobe - PROPN - nmod - Kobe - Xxxx
# Bryant - PROPN - flat:name - Bryant - Xxxxx
# vs - ADP - case - vs - xx
# Paul - PROPN - nmod - Paul - Xxxx
# Pierce - PROPN - flat:name - Pierce - Xxxxx

# %% [markdown]
# ## Entidades nomeadas

# %%
for ent in tokens_doc.ents:
  print(f'{ent.text} - {ent.label_}')
# Out:
# Lakers - ORG
# Boston Celtics - ORG
# Kobe Bryant - PER
# Paul Pierce - PER

# %% [markdown]
# ## Stop Words

# %%
# Acessando stop words
for token in tokens_doc:
  if token.is_stop:
    print(token)
# Out:
# tem
# do
# do
# tempo
# de

# %%
# Mostrando a lista de stopwords que o modelo baixado contém
#for stop_word in nlp.Defaults.stop_words:
  #print(stop_word)

print(len(nlp.Defaults.stop_words))
# Out:
# 416

# %%
# Adicionando uma stop word na lista. Suponha que Eita não exista na lista e que vc considera ela como uma stop word
#nlp.Defaults.stop_words.add('Eita')
#nlp.vocab['Eita'].is_stop = True

# %%
# Removendo stop words de um texto

print(f'{[token for token in tokens_doc if not token.is_stop]}')
# Out:
# [Hoje, jogo, Lakers, x, Boston, Celtics, ., Saudades, Kobe, Bryant, vs, Paul, Pierce]

# %% [markdown]
# ## Vocabulary

# %%
# Acessando hashs de palavras

print(f'Hash: {nlp.vocab.strings["Saudades"]}')
print(f'Hash: {tokens_doc.vocab.strings["Saudades"]}')
# Out:
# Hash: 5746622219371353673
# Hash: 5746622219371353673

# %%
# Acessando palavras a partir do hash
print(f'Palavra: {nlp.vocab.strings[5746622219371353673]}')
# Out:
# Palavra: Saudades

# %% [markdown]
# ## Similaridades

# %%
# A similaridade retorna um valor (métrica de similaridade, que no caso é a métrica de cosseno) do quão similar duas frases são

# %%
documento1 = nlp('Ele viaja de carro')
documento2 = nlp('Ela viaja de caminhão')

print(documento1.similarity(documento2))
# Out:
# 0.8956823758373116

# %%
# Similaridades entre tokens
documento3 = nlp('Devemos dizer comprimento ou cumprimento?')
token1 = documento3[2]
token2 = documento3[4]
print(f'Similaridade entre tokens: {token1.similarity(token2)}')
# Out:
# Similaridade entre tokens: 0.5804340243339539

# %%
# Similaridade entre spans (intervalos de frases)
documento4 = nlp('Ele pede descrição. Ela pede discrição')

intervalo1 = documento4[0:3]
intervalo2 = documento4[4:7]
print(f'Similaridade entre spans: {intervalo1.similarity(intervalo2)}')
# Out:
# Similaridade entre spans: 0.8453987836837769

# %% [markdown]
# ## Displacy

# %%
from spacy import displacy

# %%
# style = 'ent' (entidades nomeadas) e style = 'dep' (dependencias de tokens)
displacy.render(tokens_doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Hoje tem jogo do
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lakers
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  x
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Boston Celtics
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . Saudades do tempo de
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kobe Bryant
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  vs
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Paul Pierce
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# </div></span>

# %%
#tokens_doc.user_data['title'] = 'Dependencias de tokens' # titulo
displacy.render(tokens_doc, style='dep', jupyter=True, 
                options={'compact': True, 'distance':80, 'color': '#8B0000', 'bg': '#B0C4DE'})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pt" id="2945738e222d41079e9ee993359c11a3-0" class="displacy" width="1410" height="297.0" direction="ltr" style="max-width: none; height: 297.0px; color: #8B0000; background: #B0C4DE; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Hoje</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">tem</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">jogo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">do</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">Lakers</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">x</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">Boston</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">Celtics.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="690">Saudades</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="690">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">do</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">tempo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">Kobe</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="1090">Bryant</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1090">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="1170">vs</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1170">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">Paul</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="1330">Pierce</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1330">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2945738e222d41079e9ee993359c11a3-0-0" stroke-width="2px" d="M62,162.0 62,148.66666666666666 121.0,148.66666666666666 121.0,162.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2945738e222d41079e9ee993359c11a3-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,164.0 L58,156.0 66,156.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2945738e222d41079e9ee993359c11a3-0-1" stroke-width="2px" d="M142,162.0 142,148.66666666666666 201.0,148.66666666666666 201.0,162.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2945738e222d41079e9ee993359c11a3-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M201.0,164.0 L205.0,156.0 197.0,156.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2945738e222d41079e9ee993359c11a3-0-2" stroke-width="2px" d="M302,162.0 302,148.66666666666666 361.0,148.66666666666666 361.0,162.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2945738e222d41079e9ee993359c11a3-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M302,164.0 L298,156.0 306,156.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2945738e222d41079e9ee993359c11a3-0-3" stroke-width="2px" d="M222,162.0 222,135.33333333333334 364.0,135.33333333333334 364.0,162.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2945738e222d41079e9ee993359c11a3-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M364.0,164.0 L368.0,156.0 360.0,156.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2945738e222d41079e9ee993359c11a3-0-4" stroke-width="2px" d="M382,162.0 382,148.66666666666666 441.0,148.66666666666666 441.0,162.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2945738e222d41079e9ee993359c11a3-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">flat:name</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M441.0,164.0 L445.0,156.0 437.0,156.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2945738e222d41079e9ee993359c11a3-0-5" stroke-width="2px" d="M382,162.0 382,135.33333333333334 524.0,135.33333333333334 524.0,162.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2945738e222d41079e9ee993359c11a3-0-5" class="displacy-label" startOffset="50%" side=

# %% [markdown]
# ## Gerenciando Pipelines no Spacy

# %%
# Pipeline normal
print(nlp.pipe_names)
# Out:
# ['tok2vec', 'morphologizer', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
# Removendo passos do pipeline
print(nlp.remove_pipe('tok2vec'))
print(nlp.pipe_names)
# Out:
# ('tok2vec', <spacy.pipeline.tok2vec.Tok2Vec object at 0x7f730f42de80>)
# ['morphologizer', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
# Adicionando passos ao pipeline
print(nlp.add_pipe('tok2vec', before='morphologizer')) # adiciona ao final, para escolher a posição, basta colocar o parâmetro "after" ou "before"
print(nlp.pipe_names)
# Out:
# <spacy.pipeline.tok2vec.Tok2Vec object at 0x7f730236dc40>
# ['tok2vec', 'morphologizer', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']
